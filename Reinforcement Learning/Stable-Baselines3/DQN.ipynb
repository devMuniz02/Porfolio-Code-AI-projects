# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (2.7.0)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: cloudpickle in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from stable-baselines3[extra]) (2.3.1)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from stable-baselines3[extra]) (2.8.0)
# Requirement already satisfied: matplotlib in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from stable-baselines3[extra]) (3.10.5)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from stable-baselines3[extra]) (2.2.6)
# Requirement already satisfied: pillow in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from stable-baselines3[extra]) (11.3.0)
# Collecting ale-py>=0.9.0
#   Downloading ale_py-0.11.2-cp310-cp310-win_amd64.whl (3.5 MB)
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      - -------------------------------------- 0.1/3.5 MB 1.8 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.5/3.5 MB 5.3 MB/s eta 0:00:01
#      --------- ------------------------------ 0.8/3.5 MB 6.6 MB/s eta 0:00:01
#      ----------- ---------------------------- 1.0/3.5 MB 5.6 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.5/3.5 MB 6.9 MB/s eta 0:00:01
#      ------------------------ --------------- 2.1/3.5 MB 8.3 MB/s eta 0:00:01
#      ------------------------- -------------- 2.2/3.5 MB 8.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 3.0/3.5 MB 8.4 MB/s eta 0:00:01
#      -------------------------------------- - 3.4/3.5 MB 8.6 MB/s eta 0:00:01
#      ---------------------------------------  3.5/3.5 MB 8.2 MB/s eta 0:00:01
#      ---------------------------------------- 3.5/3.5 MB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from stable-baselines3[extra]) (7.0.0)
# Requirement already satisfied: pygame in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: opencv-python in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from stable-baselines3[extra]) (4.12.0.88)
# Collecting rich
#   Downloading rich-14.1.0-py3-none-any.whl (243 kB)
#      ---------------------------------------- 0.0/243.4 kB ? eta -:--:--
#      -------------------------------------- 243.4/243.4 kB 7.3 MB/s eta 0:00:00
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting tensorboard>=2.9.1
#   Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#      ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#      -- ------------------------------------- 0.3/5.5 MB 10.9 MB/s eta 0:00:01
#      ----- ---------------------------------- 0.8/5.5 MB 12.7 MB/s eta 0:00:01
#      -------- ------------------------------- 1.2/5.5 MB 10.8 MB/s eta 0:00:01
#      ----------- ---------------------------- 1.6/5.5 MB 11.4 MB/s eta 0:00:01
#      -------------- ------------------------- 2.0/5.5 MB 10.8 MB/s eta 0:00:01
#      ------------------ --------------------- 2.5/5.5 MB 10.6 MB/s eta 0:00:01
#      --------------------- ------------------ 3.0/5.5 MB 10.6 MB/s eta 0:00:01
#      ------------------------ --------------- 3.4/5.5 MB 10.9 MB/s eta 0:00:01
#      --------------------------- ------------ 3.8/5.5 MB 10.7 MB/s eta 0:00:01
#      ------------------------------ --------- 4.3/5.5 MB 10.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 4.7/5.5 MB 10.8 MB/s eta 0:00:01
#      ------------------------------------- -- 5.1/5.5 MB 10.9 MB/s eta 0:00:01
#      ---------------------------------------  5.5/5.5 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------------- 5.5/5.5 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from ale-py>=0.9.0->stable-baselines3[extra]) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Collecting absl-py>=0.4
#   Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#      ---------------------------------------- 0.0/135.8 kB ? eta -:--:--
#      -------------------------------------- 135.8/135.8 kB 7.8 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      ---------------------------------------- 0.0/224.5 kB ? eta -:--:--
#      -------------------------------------- 224.5/224.5 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (25.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.74.0-cp310-cp310-win_amd64.whl (4.5 MB)
#      ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#      ---- ----------------------------------- 0.5/4.5 MB 15.2 MB/s eta 0:00:01
#      -------- ------------------------------- 1.0/4.5 MB 12.5 MB/s eta 0:00:01
#      ------------- -------------------------- 1.5/4.5 MB 11.6 MB/s eta 0:00:01
#      ----------------- ---------------------- 2.0/4.5 MB 11.3 MB/s eta 0:00:01
#      ---------------------- ----------------- 2.5/4.5 MB 11.3 MB/s eta 0:00:01
#      -------------------------- ------------- 2.9/4.5 MB 11.7 MB/s eta 0:00:01
#      ------------------------------- -------- 3.5/4.5 MB 12.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 3.9/4.5 MB 11.3 MB/s eta 0:00:01
#      ---------------------------------------  4.4/4.5 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------------- 4.5/4.5 MB 11.5 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading markdown-3.8.2-py3-none-any.whl (106 kB)
#      ---------------------------------------- 0.0/106.8 kB ? eta -:--:--
#      -------------------------------------- 106.8/106.8 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (65.5.0)
# Collecting protobuf!=4.24.0,>=3.19.6
#   Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl (435 kB)
#      ---------------------------------------- 0.0/435.7 kB ? eta -:--:--
#      ------------------------------------- 435.7/435.7 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.19.1)
# Requirement already satisfied: fsspec in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.7.0)
# Requirement already satisfied: jinja2 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: networkx in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.14.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.59.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.2.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
#      ---------------------------------------- 0.0/87.3 kB ? eta -:--:--
#      ---------------------------------------- 87.3/87.3 kB ? eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from rich->stable-baselines3[extra]) (2.19.2)
# Requirement already satisfied: colorama in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six>=1.5 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\emman\desktop\proyectos_vs_code\pruebas_de_python\portfolio-venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Installing collected packages: werkzeug, tqdm, tensorboard-data-server, protobuf, mdurl, markdown, grpcio, ale-py, absl-py, tensorboard, markdown-it-py, rich
# Successfully installed absl-py-2.3.1 ale-py-0.11.2 grpcio-1.74.0 markdown-3.8.2 markdown-it-py-4.0.0 mdurl-0.1.2 protobuf-6.32.0 rich-14.1.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tqdm-4.67.1 werkzeug-3.1.3

# %%
# SimpleLander-v0: LunarLander-like env WITHOUT Box2D
# - 8D observation: [x, y, x_dot, y_dot, angle, angle_dot, left_contact, right_contact]
# - Discrete(4) actions: 0=noop, 1=left thruster, 2=main thruster, 3=right thruster
# - Minimal 2D physics + simple rgb_array renderer
# - Train DQN, evaluate, and save MP4 + GIF (≤ 100 MB)

import os, math, io, sys, subprocess, importlib
import numpy as np
import gymnasium as gym
from gymnasium import spaces
from gymnasium.envs.registration import register

# Ensure video deps
def ensure(spec, import_name=None):
    try:
        importlib.import_module(import_name or spec.split("[")[0])
    except Exception:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", spec])
try:
    import imageio.v2 as imageio
except Exception:
    ensure("imageio"); import imageio.v2 as imageio
try:
    import imageio_ffmpeg  # noqa: F401
except Exception:
    ensure("imageio-ffmpeg"); import imageio_ffmpeg
try:
    from PIL import Image, ImageDraw
except Exception:
    ensure("Pillow"); from PIL import Image, ImageDraw

# ------------------ Box2D-free Lander ------------------
class SimpleLanderEnv(gym.Env):
    """
    A lightweight, Box2D-free clone of LunarLander with similar API.
    This is NOT identical physics, but close enough for algorithm testing.
    """
    metadata = {"render_modes": ["rgb_array"], "render_fps": 30}

    def __init__(self, render_mode=None, seed=None):
        super().__init__()
        self.render_mode = render_mode
        self.dt = 1.0 / 30.0
        self.g = -9.0

        # World bounds (normalized): x in [-1.5, 1.5], y in [0, 1.4]
        self.x_min, self.x_max = -1.5, 1.5
        self.y_min, self.y_max = 0.0, 1.4
        self.ground_y = 0.0

        # Thruster strengths
        self.main_acc = 20.0     # upward
        self.side_acc = 6.0      # lateral accel
        self.torque = 6.0        # angular accel

        # State: x, y, x_dot, y_dot, angle, angle_dot, left_contact, right_contact
        high = np.array([np.inf]*6 + [1.0, 1.0], dtype=np.float32)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)
        self.action_space = spaces.Discrete(4)

        # Rendering
        self._width, self._height = 600, 400
        self._last_action = 0

        # Episode management
        self.max_steps = 1000
        self.steps = 0
        self.np_random, _ = gym.utils.seeding.np_random(seed)

        self.state = None

    def reset(self, seed=None, options=None):
        if seed is not None:
            self.np_random, _ = gym.utils.seeding.np_random(seed)
        # Start near the top, small random offset and small initial rotation
        x = float(self.np_random.uniform(-0.3, 0.3))
        y = float(self.np_random.uniform(1.0, 1.2))
        x_dot = float(self.np_random.uniform(-0.5, 0.5))
        y_dot = float(self.np_random.uniform(-0.2, 0.2))
        angle = float(self.np_random.uniform(-0.1, 0.1))
        angle_dot = float(self.np_random.uniform(-0.2, 0.2))
        left_contact = 0.0
        right_contact = 0.0

        self.state = np.array([x, y, x_dot, y_dot, angle, angle_dot, left_contact, right_contact], dtype=np.float32)
        self.steps = 0
        self._last_action = 0
        return self.state.copy(), {}

    def step(self, action: int):
        self.steps += 1
        action = int(action)
        x, y, x_dot, y_dot, angle, angle_dot, left_c, right_c = self.state

        # Thrusters
        ax = 0.0
        ay = self.g
        a_angle = 0.0

        if action == 2:  # main thruster
            ay += self.main_acc
        elif action == 1:  # left thruster -> push right and rotate CCW
            ax += self.side_acc
            a_angle += self.torque
        elif action == 3:  # right thruster -> push left and rotate CW
            ax -= self.side_acc
            a_angle -= self.torque

        # Integrate
        x_dot += ax * self.dt
        y_dot += ay * self.dt
        angle_dot += a_angle * self.dt

        x += x_dot * self.dt
        y += y_dot * self.dt
        angle += angle_dot * self.dt

        # Simple drag to stabilize learning
        x_dot *= 0.995
        y_dot *= 0.995
        angle_dot *= 0.995

        # Keep within bounds horizontally
        x = float(np.clip(x, self.x_min, self.x_max))
        # Ground collision
        terminated = False
        success = False
        if y <= self.ground_y:
            y = self.ground_y
            # contact flags
            left_c = right_c = 1.0
            # landing conditions
            if abs(x) < 0.2 and abs(x_dot) < 0.5 and abs(y_dot) < 0.5 and abs(angle) < 0.2:
                reward = 100.0  # successful landing
                success = True
            else:
                reward = -100.0  # crash
            terminated = True
            y_dot = 0.0
            angle_dot = 0.0
        else:
            # Shaping reward while airborne
            shaping = - (abs(x)*1.0 + abs(y - 0.2)*0.5 + abs(x_dot)*0.1 + abs(y_dot)*0.2 + abs(angle)*0.3 + abs(angle_dot)*0.1)
            # Small action penalty to discourage fuel use
            act_pen = -0.01 * (action != 0)
            reward = shaping + act_pen

        truncated = self.steps >= self.max_steps
        self.state = np.array([x, y, x_dot, y_dot, angle, angle_dot, left_c, right_c], dtype=np.float32)
        self._last_action = action

        info = {"is_success": success}
        return self.state.copy(), float(reward), bool(terminated), bool(truncated), info

    # -------- Rendering (rgb_array) --------
    def render(self):
        return self._get_frame()

    def _world_to_px(self, x, y):
        # Map world coordinates to pixels
        px = int((x - self.x_min) / (self.x_max - self.x_min) * self._width)
        py = int((self.y_max - y) / (self.y_max - self.y_min) * self._height)
        return px, py

    def _get_frame(self):
        img = Image.new("RGB", (self._width, self._height), (15, 18, 30))
        draw = ImageDraw.Draw(img)
        # Ground
        gy_px = self._world_to_px(0, self.ground_y)[1]
        draw.rectangle([0, gy_px, self._width, self._height], fill=(35, 70, 35))

        # Lander as a triangle
        x, y, x_dot, y_dot, angle, angle_dot, left_c, right_c = self.state
        cx, cy = self._world_to_px(x, y)
        size = 18  # pixel size
        # Triangle points before rotation (upright)
        pts = np.array([[0, -size], [-size/2, size/2], [size/2, size/2]], dtype=np.float32)
        c, s = math.cos(angle), math.sin(angle)
        rot = np.array([[c, -s], [s, c]], dtype=np.float32)
        pts = (pts @ rot.T) + np.array([cx, cy], dtype=np.float32)

        draw.polygon([tuple(p) for p in pts], outline=(220, 220, 220), fill=(180, 180, 200))

        # Flames
        if self._last_action == 2:  # main
            flame = np.array([[0, size/2], [-6, size], [6, size]], dtype=np.float32)
            flame = (flame @ rot.T) + np.array([cx, cy], dtype=np.float32)
            draw.polygon([tuple(p) for p in flame], fill=(255, 140, 0))
        elif self._last_action == 1:  # left
            flame = np.array([[size/2, 0], [size, -6], [size, 6]], dtype=np.float32)
            flame = (flame @ rot.T) + np.array([cx, cy], dtype=np.float32)
            draw.polygon([tuple(p) for p in flame], fill=(255, 120, 0))
        elif self._last_action == 3:  # right
            flame = np.array([[-size/2, 0], [-size, -6], [-size, 6]], dtype=np.float32)
            flame = (flame @ rot.T) + np.array([cx, cy], dtype=np.float32)
            draw.polygon([tuple(p) for p in flame], fill=(255, 120, 0))

        return np.array(img, dtype=np.uint8)

    def close(self):
        pass

# Register once (safe if re-run)
try:
    register(id="SimpleLander-v0", entry_point=SimpleLanderEnv)
except Exception:
    pass  # already registered

# ------------------ Train & Evaluate with SB3 DQN ------------------
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# Train (no rendering)
env = gym.make("SimpleLander-v0")
model = DQN("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=5_000, progress_bar=False)  # increase for better results
env.close()

# Evaluate
eval_env = gym.make("SimpleLander-v0")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=5)
print(f"Evaluation on SimpleLander-v0: mean={mean_reward:.2f} ± {std_reward:.2f}")
eval_env.close()

# ------------------ Record MP4 + GIF ≤ 100 MB ------------------
render_env = gym.make("SimpleLander-v0", render_mode="rgb_array")
fps = render_env.metadata.get("render_fps", 30)
obs, info = render_env.reset()
frames = []
done = False
max_frames = 1500
while not done and len(frames) < max_frames:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = render_env.step(action)
    frames.append(render_env.render())
    done = terminated or truncated
render_env.close()
print(f"Captured {len(frames)} frames @ ~{fps} FPS")

MP4_PATH = "simple_lander_policy.mp4"
GIF_PATH = "simple_lander_policy.gif"
MAX_MB = 100
MIN_FPS = 3

def file_mb(path): return os.path.getsize(path)/(1024*1024) if os.path.exists(path) else 0.0

def write_mp4(frames, fps, path):
    w = imageio.get_writer(path, format="mp4", fps=fps)
    for f in frames: w.append_data(f)
    w.close()

def fit_under_cap_by_fps(frames, orig_fps, writer_fn, out_path, max_mb=100, min_fps=3, step=5, is_gif=False):
    attempts = []
    for target_fps in list(range(int(orig_fps), min_fps-1, -step)) + ([min_fps] if (int(orig_fps)-min_fps) % step else []):
        stride = max(1, math.ceil(orig_fps / target_fps))
        sub = frames[::stride]
        if is_gif:
            imageio.mimsave(out_path, sub, format="gif", duration=1.0/max(1, target_fps))
        else:
            writer_fn(sub, target_fps, out_path)
        size = file_mb(out_path)
        attempts.append((target_fps, len(sub), size))
        if size <= max_mb:
            return True, attempts
    return False, attempts

# MP4
write_mp4(frames, fps, MP4_PATH)
if file_mb(MP4_PATH) > MAX_MB:
    ok, attempts = fit_under_cap_by_fps(frames, fps, write_mp4, MP4_PATH, MAX_MB, MIN_FPS, is_gif=False)
    print("MP4 attempts (fps, frames_kept, size_MB):")
    for a in attempts: print(f"  - {a[0]:>2} fps | {a[1]:>4} frames | {a[2]:6.2f} MB")
print(f"MP4 final size: {file_mb(MP4_PATH):.2f} MB")

# GIF
ok, attempts = fit_under_cap_by_fps(frames, fps, None, GIF_PATH, MAX_MB, MIN_FPS, is_gif=True)
print("GIF attempts (fps, frames_kept, size_MB):")
for a in attempts: print(f"  - {a[0]:>2} fps | {a[1]:>4} frames | {a[2]:6.2f} MB")
print(f"GIF final size: {file_mb(GIF_PATH):.2f} MB")

print("Saved:", MP4_PATH, GIF_PATH)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# --------------------------------------------
# | rollout/            |                    |
# |    ep_len_mean      | 19.5               |
# |    ep_rew_mean      | -115               |
# |    exploration_rate | 0.852              |
# |    success_rate     | 0                  |
# | time/               |                    |
# |    episodes         | 4                  |
# |    fps              | 351280770934898688 |
# |    time_elapsed     | 0                  |
# |    total_timesteps  | 78                 |
# --------------------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.688    |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2115     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 164      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.53     |
# |    n_updates        | 15       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.502    |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2341     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 262      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.38     |
# |    n_updates        | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.369    |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2442     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 332      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.47     |
# |    n_updates        | 57       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.234    |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2535     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 403      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.31     |
# |    n_updates        | 75       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.113    |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2552     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 467      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.38     |
# |    n_updates        | 91       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2585     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 528      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.29     |
# |    n_updates        | 106      |
# ----------------------------------
# c:\Users\emman\Desktop\PROYECTOS_VS_CODE\PRUEBAS_DE_PYTHON\PORTFOLIO-venv\lib\site-packages\gymnasium\envs\registration.py:636: UserWarning: WARN: Overriding environment SimpleLander-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2594     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 600      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.32     |
# |    n_updates        | 124      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2456     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 703      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.112    |
# |    n_updates        | 150      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2523     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 811      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.5     |
# |    n_updates        | 177      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2459     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 901      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.6     |
# |    n_updates        | 200      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2533     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 971      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.22     |
# |    n_updates        | 217      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2505     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1033     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.4     |
# |    n_updates        | 233      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2528     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1099     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.14     |
# |    n_updates        | 249      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2562     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1163     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.21     |
# |    n_updates        | 265      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2521     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1230     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 282      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2510     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1297     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 299      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2517     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1358     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.2      |
# |    n_updates        | 314      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2568     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1420     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 329      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2526     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1481     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.25     |
# |    n_updates        | 345      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2564     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1542     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.24     |
# |    n_updates        | 360      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2542     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1603     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.17     |
# |    n_updates        | 375      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2557     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1665     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.16     |
# |    n_updates        | 391      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2599     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1737     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 409      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2577     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1811     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.08     |
# |    n_updates        | 427      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2616     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1878     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.08     |
# |    n_updates        | 444      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2581     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1938     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.17     |
# |    n_updates        | 459      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2611     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2009     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.16     |
# |    n_updates        | 477      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2609     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2084     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.15     |
# |    n_updates        | 495      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2602     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2171     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.25     |
# |    n_updates        | 517      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2596     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2237     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0139   |
# |    n_updates        | 534      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2605     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2319     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.3     |
# |    n_updates        | 554      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2615     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2443     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.019    |
# |    n_updates        | 585      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2636     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2603     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.08     |
# |    n_updates        | 625      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2645     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2775     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.16     |
# |    n_updates        | 668      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.6     |
# |    ep_rew_mean      | -223     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2699     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3364     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.17     |
# |    n_updates        | 815      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | -223     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2699     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3424     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.21     |
# |    n_updates        | 830      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | -223     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2707     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3485     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 846      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | -223     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2686     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3546     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.11     |
# |    n_updates        | 861      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2706     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3606     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.17     |
# |    n_updates        | 876      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2710     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3665     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.25     |
# |    n_updates        | 891      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2690     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3727     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.21     |
# |    n_updates        | 906      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2686     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3791     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.22     |
# |    n_updates        | 922      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2683     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3852     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.23     |
# |    n_updates        | 937      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2696     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3917     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0524   |
# |    n_updates        | 954      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2679     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3977     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.12     |
# |    n_updates        | 969      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2680     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4035     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.09     |
# |    n_updates        | 983      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2695     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4094     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.3      |
# |    n_updates        | 998      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2685     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4154     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0562   |
# |    n_updates        | 1013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2684     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4214     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.18     |
# |    n_updates        | 1028     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 2696     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4276     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.21     |
# |    n_updates        | 1043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 2678     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4336     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.28     |
# |    n_updates        | 1058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 2688     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4397     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.15     |
# |    n_updates        | 1074     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | -221     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2677     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4460     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.27     |
# |    n_updates        | 1089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | -221     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2678     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4519     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.3     |
# |    n_updates        | 1104     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | -221     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 2678     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4578     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.206    |
# |    n_updates        | 1119     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | -221     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 2698     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4639     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.24     |
# |    n_updates        | 1134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | -221     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 2683     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4700     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.17     |
# |    n_updates        | 1149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | -220     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 2677     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4765     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.16     |
# |    n_updates        | 1166     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | -220     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 2677     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4826     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.11     |
# |    n_updates        | 1181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | -113     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 2680     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4884     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.17     |
# |    n_updates        | 1195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | -113     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0        |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 2683     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4947     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.4     |
# |    n_updates        | 1211     |
# ----------------------------------
# Evaluation on SimpleLander-v0: mean=-112.27 ± 1.52
# Captured 15 frames @ ~30 FPS
# c:\Users\emman\Desktop\PROYECTOS_VS_CODE\PRUEBAS_DE_PYTHON\PORTFOLIO-venv\lib\site-packages\stable_baselines3\common\evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# MP4 final size: 0.00 MB
# GIF attempts (fps, frames_kept, size_MB):
#   - 30 fps |   15 frames |   0.00 MB
# GIF final size: 0.00 MB
# Saved: simple_lander_policy.mp4 simple_lander_policy.gif
