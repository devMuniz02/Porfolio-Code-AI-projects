# %%
# !pip install -q imitation gymnasium
import numpy as np
from imitation.policies.serialize import load_policy
from imitation.util.util import make_vec_env
from imitation.data.wrappers import RolloutInfoWrapper

SEED = 42

env = make_vec_env(
    "seals:seals/CartPole-v0",
    rng=np.random.default_rng(SEED),
    n_envs=8,
    post_wrappers=[
        lambda env, _: RolloutInfoWrapper(env)
    ],  # needed for computing rollouts later
)
expert = load_policy(
    "ppo-huggingface",
    organization="HumanCompatibleAI",
    env_name="seals/CartPole-v0",
    venv=env,
)

from imitation.data import rollout

rollouts = rollout.rollout(
    expert,
    env,
    rollout.make_sample_until(min_timesteps=None, min_episodes=60),
    rng=np.random.default_rng(SEED),
)

from imitation.algorithms.adversarial.gail import GAIL
from imitation.rewards.reward_nets import BasicRewardNet
from imitation.util.networks import RunningNorm
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy

learner = PPO(
    env=env,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0004,
    gamma=0.95,
    n_epochs=5,
    seed=SEED,
)
reward_net = BasicRewardNet(
    observation_space=env.observation_space,
    action_space=env.action_space,
    normalize_input_layer=RunningNorm,
)
gail_trainer = GAIL(
    demonstrations=rollouts,
    demo_batch_size=1024,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=8,
    venv=env,
    gen_algo=learner,
    reward_net=reward_net,
)

env.seed(SEED)
learner_rewards_before_training, _ = evaluate_policy(
    learner, env, 100, return_episode_rewards=True
)

gail_trainer.train(200_000)

env.seed(SEED)
learner_rewards_after_training, _ = evaluate_policy(
    learner, env, 100, return_episode_rewards=True
)

print(
    "Rewards before training:",
    np.mean(learner_rewards_before_training),
    "+/-",
    np.std(learner_rewards_before_training),
)
print(
    "Rewards after training:",
    np.mean(learner_rewards_after_training),
    "+/-",
    np.std(learner_rewards_after_training),
)
# Out:
# 2025-01-05 01:15:00.282035: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# round:   0%|          | 0/12 [00:00<?, ?it/s]
# ------------------------------------------
# | raw/                        |          |
# |    gen/rollout/ep_len_mean  | 500      |
# |    gen/rollout/ep_rew_mean  | 29.8     |
# |    gen/time/fps             | 2605     |
# |    gen/time/iterations      | 1        |
# |    gen/time/time_elapsed    | 6        |
# |    gen/time/total_timesteps | 16384    |
# ------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.696    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.694    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.693    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.69     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.688    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.686    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.684    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.683    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.689    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 29.8     |
# |    gen/time/fps                     | 2.6e+03  |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 6        |
# |    gen/time/total_timesteps         | 1.64e+04 |
# |    gen/train/approx_kl              | 0.00905  |
# |    gen/train/clip_fraction          | 0.0295   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.686   |
# |    gen/train/explained_variance     | 0.0301   |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.127    |
# |    gen/train/n_updates              | 5        |
# |    gen/train/policy_gradient_loss   | -0.0015  |
# |    gen/train/value_loss             | 4.43     |
# --------------------------------------------------
# round:   8%|▊         | 1/12 [00:16<02:57, 16.11s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 31.9        |
# |    gen/rollout/ep_rew_wrapped_mean | 268         |
# |    gen/time/fps                    | 3144        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 5           |
# |    gen/time/total_timesteps        | 32768       |
# |    gen/train/approx_kl             | 0.009048734 |
# |    gen/train/clip_fraction         | 0.0295      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.686      |
# |    gen/train/explained_variance    | 0.0301      |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.127       |
# |    gen/train/n_updates             | 5           |
# |    gen/train/policy_gradient_loss  | -0.0015     |
# |    gen/train/value_loss            | 4.43        |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.685    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.684    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.683    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.682    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.68     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.68     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.679    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.678    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.681    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 31.9     |
# |    gen/rollout/ep_rew_wrapped_mean  | 268      |
# |    gen/time/fps                     | 3.14e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 5        |
# |    gen/time/total_timesteps         | 3.28e+04 |
# |    gen/train/approx_kl              | 0.0107   |
# |    gen/train/clip_fraction          | 0.132    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.686   |
# |    gen/train/explained_variance     | 0.841    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0172   |
# |    gen/train/n_updates              | 10       |
# |    gen/train/policy_gradient_loss   | -0.00802 |
# |    gen/train/value_loss             | 0.247    |
# --------------------------------------------------
# round:  17%|█▋        | 2/12 [00:28<02:16, 13.68s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 33.9        |
# |    gen/rollout/ep_rew_wrapped_mean | 275         |
# |    gen/time/fps                    | 2558        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 6           |
# |    gen/time/total_timesteps        | 49152       |
# |    gen/train/approx_kl             | 0.010725586 |
# |    gen/train/clip_fraction         | 0.132       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.686      |
# |    gen/train/explained_variance    | 0.841       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0172      |
# |    gen/train/n_updates             | 10          |
# |    gen/train/policy_gradient_loss  | -0.00802    |
# |    gen/train/value_loss            | 0.247       |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.673    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.673    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.671    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.669    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.668    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.668    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.664    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.663    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.669    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 33.9     |
# |    gen/rollout/ep_rew_wrapped_mean  | 275      |
# |    gen/time/fps                     | 2.56e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 6        |
# |    gen/time/total_timesteps         | 4.92e+04 |
# |    gen/train/approx_kl              | 0.0161   |
# |    gen/train/clip_fraction          | 0.207    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.673   |
# |    gen/train/explained_variance     | 0.82     |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | -0.019   |
# |    gen/train/n_updates              | 15       |
# |    gen/train/policy_gradient_loss   | -0.0131  |
# |    gen/train/value_loss             | 0.0429   |
# --------------------------------------------------
# round:  25%|██▌       | 3/12 [00:43<02:11, 14.59s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 37.7        |
# |    gen/rollout/ep_rew_wrapped_mean | 277         |
# |    gen/time/fps                    | 2086        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 7           |
# |    gen/time/total_timesteps        | 65536       |
# |    gen/train/approx_kl             | 0.016089637 |
# |    gen/train/clip_fraction         | 0.207       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.673      |
# |    gen/train/explained_variance    | 0.82        |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | -0.019      |
# |    gen/train/n_updates             | 15          |
# |    gen/train/policy_gradient_loss  | -0.0131     |
# |    gen/train/value_loss            | 0.0429      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.653    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.647    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.647    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.642    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.642    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.638    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.631    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.63     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.641    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 37.7     |
# |    gen/rollout/ep_rew_wrapped_mean  | 277      |
# |    gen/time/fps                     | 2.09e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 7        |
# |    gen/time/total_timesteps         | 6.55e+04 |
# |    gen/train/approx_kl              | 0.0171   |
# |    gen/train/clip_fraction          | 0.24     |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.654   |
# |    gen/train/explained_variance     | 0.892    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | -0.0361  |
# |    gen/train/n_updates              | 20       |
# |    gen/train/policy_gradient_loss   | -0.0214  |
# |    gen/train/value_loss             | 0.0187   |
# --------------------------------------------------
# round:  33%|███▎      | 4/12 [00:58<01:58, 14.76s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 39.2        |
# |    gen/rollout/ep_rew_wrapped_mean | 283         |
# |    gen/time/fps                    | 2815        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 5           |
# |    gen/time/total_timesteps        | 81920       |
# |    gen/train/approx_kl             | 0.017104484 |
# |    gen/train/clip_fraction         | 0.24        |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.654      |
# |    gen/train/explained_variance    | 0.892       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | -0.0361     |
# |    gen/train/n_updates             | 20          |
# |    gen/train/policy_gradient_loss  | -0.0214     |
# |    gen/train/value_loss            | 0.0187      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.656    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.656    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.653    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.65     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.651    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.577    |
# |    disc/disc_acc_expert             | 0.154    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.645    |
# |    disc/disc_proportion_expert_pred | 0.0771   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.664    |
# |    disc/disc_acc_expert             | 0.331    |
# |    disc/disc_acc_gen                | 0.996    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.643    |
# |    disc/disc_proportion_expert_pred | 0.167    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.692    |
# |    disc/disc_acc_expert             | 0.401    |
# |    disc/disc_acc_gen                | 0.982    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.64     |
# |    disc/disc_proportion_expert_pred | 0.209    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.554    |
# |    disc/disc_acc_expert             | 0.111    |
# |    disc/disc_acc_gen                | 0.997    |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.649    |
# |    disc/disc_proportion_expert_pred | 0.0568   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 39.2     |
# |    gen/rollout/ep_rew_wrapped_mean  | 283      |
# |    gen/time/fps                     | 2.82e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 5        |
# |    gen/time/total_timesteps         | 8.19e+04 |
# |    gen/train/approx_kl              | 0.0107   |
# |    gen/train/clip_fraction          | 0.126    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.636   |
# |    gen/train/explained_variance     | 0.882    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | -0.0112  |
# |    gen/train/n_updates              | 25       |
# |    gen/train/policy_gradient_loss   | -0.01    |
# |    gen/train/value_loss             | 0.0116   |
# --------------------------------------------------
# round:  42%|████▏     | 5/12 [01:11<01:37, 13.88s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 37.6        |
# |    gen/rollout/ep_rew_wrapped_mean | 285         |
# |    gen/time/fps                    | 3102        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 5           |
# |    gen/time/total_timesteps        | 98304       |
# |    gen/train/approx_kl             | 0.010718755 |
# |    gen/train/clip_fraction         | 0.126       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.636      |
# |    gen/train/explained_variance    | 0.882       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | -0.0112     |
# |    gen/train/n_updates             | 25          |
# |    gen/train/policy_gradient_loss  | -0.01       |
# |    gen/train/value_loss            | 0.0116      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.73     |
# |    disc/disc_acc_expert             | 0.464    |
# |    disc/disc_acc_gen                | 0.996    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.625    |
# |    disc/disc_proportion_expert_pred | 0.234    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.72     |
# |    disc/disc_acc_expert             | 0.445    |
# |    disc/disc_acc_gen                | 0.994    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.624    |
# |    disc/disc_proportion_expert_pred | 0.226    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.738    |
# |    disc/disc_acc_expert             | 0.482    |
# |    disc/disc_acc_gen                | 0.994    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.626    |
# |    disc/disc_proportion_expert_pred | 0.244    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.74     |
# |    disc/disc_acc_expert             | 0.484    |
# |    disc/disc_acc_gen                | 0.996    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.621    |
# |    disc/disc_proportion_expert_pred | 0.244    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.73     |
# |    disc/disc_acc_expert             | 0.474    |
# |    disc/disc_acc_gen                | 0.987    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.619    |
# |    disc/disc_proportion_expert_pred | 0.243    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.777    |
# |    disc/disc_acc_expert             | 0.566    |
# |    disc/disc_acc_gen                | 0.987    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.615    |
# |    disc/disc_proportion_expert_pred | 0.29     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.836    |
# |    disc/disc_acc_expert             | 0.695    |
# |    disc/disc_acc_gen                | 0.977    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.613    |
# |    disc/disc_proportion_expert_pred | 0.359    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.858    |
# |    disc/disc_acc_expert             | 0.744    |
# |    disc/disc_acc_gen                | 0.972    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.613    |
# |    disc/disc_proportion_expert_pred | 0.386    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.766    |
# |    disc/disc_acc_expert             | 0.544    |
# |    disc/disc_acc_gen                | 0.988    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.619    |
# |    disc/disc_proportion_expert_pred | 0.278    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 37.6     |
# |    gen/rollout/ep_rew_wrapped_mean  | 285      |
# |    gen/time/fps                     | 3.1e+03  |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 5        |
# |    gen/time/total_timesteps         | 9.83e+04 |
# |    gen/train/approx_kl              | 0.00739  |
# |    gen/train/clip_fraction          | 0.0788   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.629   |
# |    gen/train/explained_variance     | 0.891    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | -0.0101  |
# |    gen/train/n_updates              | 30       |
# |    gen/train/policy_gradient_loss   | -0.00389 |
# |    gen/train/value_loss             | 0.0121   |
# --------------------------------------------------
# round:  50%|█████     | 6/12 [01:24<01:22, 13.77s/it]
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 500          |
# |    gen/rollout/ep_rew_mean         | 34.3         |
# |    gen/rollout/ep_rew_wrapped_mean | 282          |
# |    gen/time/fps                    | 3280         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 4            |
# |    gen/time/total_timesteps        | 114688       |
# |    gen/train/approx_kl             | 0.0073878746 |
# |    gen/train/clip_fraction         | 0.0788       |
# |    gen/train/clip_range            | 0.2          |
# ...
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 44.4        |
# |    gen/rollout/ep_rew_wrapped_mean | 226         |
# |    gen/time/fps                    | 2565        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 6           |
# |    gen/time/total_timesteps        | 180224      |
# |    gen/train/approx_kl             | 0.012100431 |
# |    gen/train/clip_fraction         | 0.146       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.62       |
# |    gen/train/explained_variance    | 0.925       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | -0.00326    |
# |    gen/train/n_updates             | 50          |
# |    gen/train/policy_gradient_loss  | -0.00836    |
# |    gen/train/value_loss            | 0.0602      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.788    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.575    |
# |    disc/disc_entropy                | 0.645    |
# |    disc/disc_loss                   | 0.542    |
# |    disc/disc_proportion_expert_pred | 0.712    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.791    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.581    |
# |    disc/disc_entropy                | 0.641    |
# |    disc/disc_loss                   | 0.54     |
# |    disc/disc_proportion_expert_pred | 0.709    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.794    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.588    |
# |    disc/disc_entropy                | 0.638    |
# |    disc/disc_loss                   | 0.532    |
# |    disc/disc_proportion_expert_pred | 0.706    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.781    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.562    |
# |    disc/disc_entropy                | 0.64     |
# |    disc/disc_loss                   | 0.539    |
# |    disc/disc_proportion_expert_pred | 0.719    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.788    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.575    |
# |    disc/disc_entropy                | 0.634    |
# |    disc/disc_loss                   | 0.531    |
# |    disc/disc_proportion_expert_pred | 0.712    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.783    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.566    |
# |    disc/disc_entropy                | 0.631    |
# |    disc/disc_loss                   | 0.527    |
# |    disc/disc_proportion_expert_pred | 0.717    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.787    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.573    |
# |    disc/disc_entropy                | 0.628    |
# |    disc/disc_loss                   | 0.522    |
# |    disc/disc_proportion_expert_pred | 0.713    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.775    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.551    |
# |    disc/disc_entropy                | 0.63     |
# |    disc/disc_loss                   | 0.53     |
# |    disc/disc_proportion_expert_pred | 0.725    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.786    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.572    |
# |    disc/disc_entropy                | 0.636    |
# |    disc/disc_loss                   | 0.533    |
# |    disc/disc_proportion_expert_pred | 0.714    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 44.4     |
# |    gen/rollout/ep_rew_wrapped_mean  | 226      |
# |    gen/time/fps                     | 2.56e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 6        |
# |    gen/time/total_timesteps         | 1.8e+05  |
# |    gen/train/approx_kl              | 0.016    |
# |    gen/train/clip_fraction          | 0.207    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.607   |
# |    gen/train/explained_variance     | 0.956    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0126   |
# |    gen/train/n_updates              | 55       |
# |    gen/train/policy_gradient_loss   | -0.0112  |
# |    gen/train/value_loss             | 0.0597   |
# --------------------------------------------------
# round:  92%|█████████▏| 11/12 [02:32<00:13, 13.92s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_len_mean         | 500        |
# |    gen/rollout/ep_rew_mean         | 52.9       |
# |    gen/rollout/ep_rew_wrapped_mean | 209        |
# |    gen/time/fps                    | 2621       |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 6          |
# |    gen/time/total_timesteps        | 196608     |
# |    gen/train/approx_kl             | 0.01598726 |
# |    gen/train/clip_fraction         | 0.207      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -0.607     |
# |    gen/train/explained_variance    | 0.956      |
# |    gen/train/learning_rate         | 0.0004     |
# |    gen/train/loss                  | 0.0126     |
# |    gen/train/n_updates             | 55         |
# |    gen/train/policy_gradient_loss  | -0.0112    |
# |    gen/train/value_loss            | 0.0597     |
# ---------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.623    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.245    |
# |    disc/disc_entropy                | 0.672    |
# |    disc/disc_loss                   | 0.637    |
# |    disc/disc_proportion_expert_pred | 0.877    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.643    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.285    |
# |    disc/disc_entropy                | 0.669    |
# |    disc/disc_loss                   | 0.627    |
# |    disc/disc_proportion_expert_pred | 0.857    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.629    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.258    |
# |    disc/disc_entropy                | 0.672    |
# |    disc/disc_loss                   | 0.634    |
# |    disc/disc_proportion_expert_pred | 0.871    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.63     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.261    |
# |    disc/disc_entropy                | 0.672    |
# |    disc/disc_loss                   | 0.631    |
# |    disc/disc_proportion_expert_pred | 0.87     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.641    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.281    |
# |    disc/disc_entropy                | 0.671    |
# |    disc/disc_loss                   | 0.626    |
# |    disc/disc_proportion_expert_pred | 0.859    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.642    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.284    |
# |    disc/disc_entropy                | 0.672    |
# |    disc/disc_loss                   | 0.624    |
# |    disc/disc_proportion_expert_pred | 0.858    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.653    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.306    |
# |    disc/disc_entropy                | 0.673    |
# |    disc/disc_loss                   | 0.625    |
# |    disc/disc_proportion_expert_pred | 0.847    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.657    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.314    |
# |    disc/disc_entropy                | 0.674    |
# |    disc/disc_loss                   | 0.622    |
# |    disc/disc_proportion_expert_pred | 0.843    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.64     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.279    |
# |    disc/disc_entropy                | 0.672    |
# |    disc/disc_loss                   | 0.628    |
# |    disc/disc_proportion_expert_pred | 0.86     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 52.9     |
# |    gen/rollout/ep_rew_wrapped_mean  | 209      |
# |    gen/time/fps                     | 2.62e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 6        |
# |    gen/time/total_timesteps         | 1.97e+05 |
# |    gen/train/approx_kl              | 0.0165   |
# |    gen/train/clip_fraction          | 0.214    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.582   |
# |    gen/train/explained_variance     | 0.977    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.00742  |
# |    gen/train/n_updates              | 60       |
# |    gen/train/policy_gradient_loss   | -0.0153  |
# |    gen/train/value_loss             | 0.0542   |
# --------------------------------------------------
# round: 100%|██████████| 12/12 [02:45<00:00, 13.81s/it]
# Rewards before training: 102.6 +/- 24.11514047232568
# Rewards after training: 177.13 +/- 181.77814252544223
